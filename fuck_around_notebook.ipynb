# %%
import pandas as pd

# %%
df = pd.read_csv('data/blockchain_transactions.csv')
df
# Out:
#        block_index  block_timestamp block_miner_id  \
# 0                0     1.753185e+09        genesis
# 1                1     1.753185e+09     GRID-OP-01
# 2                1     1.753185e+09     GRID-OP-01
# 3                2     1.753185e+09     GRID-OP-01
# 4                2     1.753185e+09     GRID-OP-01
# ...            ...              ...            ...
# 10201          488     1.753192e+09     GRID-OP-01
# 10202          489     1.753192e+09     GRID-OP-01
# 10203          489     1.753192e+09     GRID-OP-01
# 10204          489     1.753192e+09     GRID-OP-01
# 10205          489     1.753192e+09     GRID-OP-01
#
#                                   tx_id  tx_timestamp          tx_type  \
# 0                                   NaN           NaN              NaN
# 1      21eed0258f184cc8ab97382ff638b9a1  1.753185e+09  energy_delivery
# 2      23268eea91b84e1b847115b1515c64e4  1.753185e+09   energy_payment
# ...

# %%
df.describe()
# Out:
#         block_index  block_timestamp  tx_timestamp     tx_amount  \
# count  10206.000000     1.020600e+04  1.020500e+04  10205.000000
# mean     243.360768     1.753188e+09  1.753188e+09      0.178276
# std      140.788100     2.058512e+03  2.058298e+03      0.131802
# min        0.000000     1.753185e+09  1.753185e+09      0.002200
# 25%      122.000000     1.753187e+09  1.753187e+09      0.077414
# 50%      240.000000     1.753188e+09  1.753188e+09      0.152675
# 75%      366.000000     1.753190e+09  1.753190e+09      0.247467
# max      489.000000     1.753192e+09  1.753192e+09      1.015370
#
#           tx_energy   block_nonce
# count  10205.000000  10206.000000
# mean       0.445437    261.149422
# std        0.635558    251.152467
# min        0.000000      0.000000
# 25%        0.000000     89.000000
# 50%        0.041013    188.000000
# 75%        0.761700    365.000000
# max        4.882501   1564.000000
